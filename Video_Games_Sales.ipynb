# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df= pd.read_csv('Video Games Sales.csv')

# %%
df.head(15)
# Out:
#     index  Rank                     Game Title Platform  Year         Genre  \
# 0       0     1                     Wii Sports      Wii  2006        Sports
# 1       1     2              Super Mario Bros.      NES  1985      Platform
# 2       2     3                 Mario Kart Wii      Wii  2008        Racing
# 3       3     4              Wii Sports Resort      Wii  2009        Sports
# 4       4     5                         Tetris       GB  1989        Puzzle
# 5       5     6          New Super Mario Bros.       DS  2006      Platform
# 6       6     7                       Wii Play      Wii  2006          Misc
# 7       7     8                      Duck Hunt      NES  1984       Shooter
# 8       8     9      New Super Mario Bros. Wii      Wii  2009      Platform
# 9       9    10                     Nintendogs       DS  2005    Simulation
# 10     10    11  Pokemon Gold / Silver Version       GB  1999  Role-Playing
# ...

# %%
df[df['Game Title'].str.contains('Pokemon')]
# Out:
#       index  Rank                                         Game Title Platform  \
# 10       10    11                      Pokemon Gold / Silver Version       GB
# 19       19    20                    Pokemon Diamond / Pearl Version       DS
# 22       22    23                    Pokemon Ruby / Sapphire Version      GBA
# 26       26    27            Pokemon Yellow: Special Pikachu Edition       GB
# 27       27    28                      Pokemon Black / White Version       DS
# 38       38    39           Pokemon Heart Gold / Soul Silver Version       DS
# 45       45    46                Pokemon FireRed / LeafGreen Version      GBA
# 74       74    75                           Pokemon Platinum Version       DS
# 93       93    94                            Pokemon Emerald Version      GBA
# 94       94    95                            Pokemon Crystal Version       GB
# 95       95    96                    Pokemon Black / White Version 2       DS
# ...

# %%
df.isna().sum()
# Out:
# index            0
# Rank             0
# Game Title       0
# Platform         0
# Year             0
# Genre            0
# Publisher        0
# North America    0
# Europe           0
# Japan            0
# Rest of World    0
# Global           0
# Review           0
# dtype: int64

# %%
df.describe()
# Out:
#            index       Rank         Year  North America       Europe  \
# count  1907.0000  1907.0000  1907.000000    1907.000000  1907.000000
# mean    953.0000   954.0000  2003.769271       1.258789     0.706675
# std     550.6478   550.6478     5.871681       1.956560     1.148904
# min       0.0000     1.0000  1983.000000       0.000000     0.000000
# 25%     476.5000   477.5000  2000.500000       0.510000     0.230000
# 50%     953.0000   954.0000  2005.000000       0.810000     0.440000
# 75%    1429.5000  1430.5000  2008.000000       1.375000     0.810000
# max    1906.0000  1907.0000  2012.000000      40.430000    28.390000
#
#              Japan  Rest of World       Global       Review
# count  1907.000000    1907.000000  1907.000000  1907.000000
# mean      0.317493       0.206471     2.489240    79.038977
# std       0.724945       0.343093     3.563159    10.616899
# min       0.000000       0.000000     0.830000    30.500000
# ...
