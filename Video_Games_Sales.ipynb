# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df= pd.read_csv('Video Games Sales.csv')

# %%
df
# Out:
#       index  Rank                        Game Title Platform  Year  \
# 0         0     1                        Wii Sports      Wii  2006
# 1         1     2                 Super Mario Bros.      NES  1985
# 2         2     3                    Mario Kart Wii      Wii  2008
# 3         3     4                 Wii Sports Resort      Wii  2009
# 4         4     5                            Tetris       GB  1989
# ...     ...   ...                               ...      ...   ...
# 1902   1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004
# 1903   1903  1904              Xenoblade Chronicles      Wii  2010
# 1904   1904  1905                     SingStar Abba      PS3  2008
# 1905   1905  1906    FIFA Soccer World Championship      PS2  2000
# 1906   1906  1907        WWE SmackDown vs. Raw 2011     X360  2010
#
#              Genre                    Publisher  North America  Europe  Japan  \
# 0           Sports                     Nintendo          40.43   28.39   3.77
# ...

# %%
df.drop('index', axis= 1, inplace= True)

# %%
df
# Out:
#       Rank                        Game Title Platform  Year         Genre  \
# 0        1                        Wii Sports      Wii  2006        Sports
# 1        2                 Super Mario Bros.      NES  1985      Platform
# 2        3                    Mario Kart Wii      Wii  2008        Racing
# 3        4                 Wii Sports Resort      Wii  2009        Sports
# 4        5                            Tetris       GB  1989        Puzzle
# ...    ...                               ...      ...   ...           ...
# 1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004        Action
# 1903  1904              Xenoblade Chronicles      Wii  2010  Role-Playing
# 1904  1905                     SingStar Abba      PS3  2008          Misc
# 1905  1906    FIFA Soccer World Championship      PS2  2000        Sports
# 1906  1907        WWE SmackDown vs. Raw 2011     X360  2010      Fighting
#
#                         Publisher  North America  Europe  Japan  \
# ...

# %%
df.set_index('Rank', inplace= True)

# %%
df
# Out:
#                             Game Title Platform  Year         Genre  \
# Rank
# 1                           Wii Sports      Wii  2006        Sports
# 2                    Super Mario Bros.      NES  1985      Platform
# 3                       Mario Kart Wii      Wii  2008        Racing
# 4                    Wii Sports Resort      Wii  2009        Sports
# 5                               Tetris       GB  1989        Puzzle
# ...                                ...      ...   ...           ...
# 1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004        Action
# 1904              Xenoblade Chronicles      Wii  2010  Role-Playing
# 1905                     SingStar Abba      PS3  2008          Misc
# 1906    FIFA Soccer World Championship      PS2  2000        Sports
# 1907        WWE SmackDown vs. Raw 2011     X360  2010      Fighting
#
#                         Publisher  North America  Europe  Japan  \
# Rank
# 1                        Nintendo          40.43   28.39   3.77
# ...

# %%
df.head()
# Out:
#              Game Title Platform  Year     Genre Publisher  North America  \
# Rank
# 1            Wii Sports      Wii  2006    Sports  Nintendo          40.43
# 2     Super Mario Bros.      NES  1985  Platform  Nintendo          29.08
# 3        Mario Kart Wii      Wii  2008    Racing  Nintendo          14.50
# 4     Wii Sports Resort      Wii  2009    Sports  Nintendo          14.82
# 5                Tetris       GB  1989    Puzzle  Nintendo          23.20
#
#       Europe  Japan  Rest of World  Global  Review
# Rank
# 1      28.39   3.77           8.54   81.12   76.28
# 2       3.58   6.81           0.77   40.24   91.00
# 3      12.22   3.63           3.21   33.55   82.07
# 4      10.51   3.18           3.01   31.52   82.65
# 5       2.26   4.22           0.58   30.26   88.00

# %%
df[df['Game Title'].str.contains('Pokemon')]
# Out:
#                                              Game Title Platform  Year  \
# Rank
# 11                        Pokemon Gold / Silver Version       GB  1999
# 20                      Pokemon Diamond / Pearl Version       DS  2006
# 23                      Pokemon Ruby / Sapphire Version      GBA  2002
# 27              Pokemon Yellow: Special Pikachu Edition       GB  1998
# 28                        Pokemon Black / White Version       DS  2010
# 39             Pokemon Heart Gold / Soul Silver Version       DS  2009
# 46                  Pokemon FireRed / LeafGreen Version      GBA  2004
# 75                             Pokemon Platinum Version       DS  2008
# 94                              Pokemon Emerald Version      GBA  2004
# 95                              Pokemon Crystal Version       GB  2000
# 96                      Pokemon Black / White Version 2       DS  2012
# 130                                     Pokemon Stadium      N64  1999
# ...

# %%
df.isna().sum()
# Out:
# Game Title       0
# Platform         0
# Year             0
# Genre            0
# Publisher        0
# North America    0
# Europe           0
# Japan            0
# Rest of World    0
# Global           0
# Review           0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  North America       Europe        Japan  Rest of World  \
# count  1907.000000    1907.000000  1907.000000  1907.000000    1907.000000
# mean   2003.769271       1.258789     0.706675     0.317493       0.206471
# std       5.871681       1.956560     1.148904     0.724945       0.343093
# min    1983.000000       0.000000     0.000000     0.000000       0.000000
# 25%    2000.500000       0.510000     0.230000     0.000000       0.060000
# 50%    2005.000000       0.810000     0.440000     0.020000       0.130000
# 75%    2008.000000       1.375000     0.810000     0.300000       0.220000
# max    2012.000000      40.430000    28.390000     7.200000       8.540000
#
#             Global       Review
# count  1907.000000  1907.000000
# mean      2.489240    79.038977
# std       3.563159    10.616899
# min       0.830000    30.500000
# 25%       1.110000    74.000000
# 50%       1.530000    81.000000
# 75%       2.540000    86.230000
# ...

# %%
df.to_csv('Video_Games_Sales_new.csv')

# %%
df2= pd.read_csv('Video_Games_Sales_new.csv')

# %%
df2
# Out:
#       Rank                        Game Title Platform  Year         Genre  \
# 0        1                        Wii Sports      Wii  2006        Sports
# 1        2                 Super Mario Bros.      NES  1985      Platform
# 2        3                    Mario Kart Wii      Wii  2008        Racing
# 3        4                 Wii Sports Resort      Wii  2009        Sports
# 4        5                            Tetris       GB  1989        Puzzle
# ...    ...                               ...      ...   ...           ...
# 1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004        Action
# 1903  1904              Xenoblade Chronicles      Wii  2010  Role-Playing
# 1904  1905                     SingStar Abba      PS3  2008          Misc
# 1905  1906    FIFA Soccer World Championship      PS2  2000        Sports
# 1906  1907        WWE SmackDown vs. Raw 2011     X360  2010      Fighting
#
#                         Publisher  North America  Europe  Japan  \
# ...

# %%
df2['Game Title'].str.contains('wii', case= False)
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1902    False
# 1903    False
# 1904    False
# 1905    False
# 1906    False
# Name: Game Title, Length: 1907, dtype: bool

# %%
if (df2['Game Title'].str.contains('wii', case= False) == True).any():
    print(df2[df2['Game Title'].str.contains('wii', case= False)])
# Out:
#       Rank                         Game Title Platform  Year      Genre  \
# 0        1                         Wii Sports      Wii  2006     Sports
# 2        3                     Mario Kart Wii      Wii  2008     Racing
# 3        4                  Wii Sports Resort      Wii  2009     Sports
# 6        7                           Wii Play      Wii  2006       Misc
# 8        9          New Super Mario Bros. Wii      Wii  2009   Platform
# 11      12                            Wii Fit      Wii  2007     Sports
# 13      14                       Wii Fit Plus      Wii  2009     Sports
# 64      65                          Wii Party      Wii  2010       Misc
# 260    261      Big Brain Academy: Wii Degree      Wii  2007       Misc
# 337    338                          Wii Music      Wii  2008       Misc
# 1323  1324  PokePark Wii: Pikachu's Adventure      Wii  2009  Adventure
#
#      Publisher  North America  Europe  Japan  Rest of World  Global  Review
# ...

# %%
df2[df2['Game Title'].str.contains('wii', case= False)]
# Out:
#       Rank                         Game Title Platform  Year      Genre  \
# 0        1                         Wii Sports      Wii  2006     Sports
# 2        3                     Mario Kart Wii      Wii  2008     Racing
# 3        4                  Wii Sports Resort      Wii  2009     Sports
# 6        7                           Wii Play      Wii  2006       Misc
# 8        9          New Super Mario Bros. Wii      Wii  2009   Platform
# 11      12                            Wii Fit      Wii  2007     Sports
# 13      14                       Wii Fit Plus      Wii  2009     Sports
# 64      65                          Wii Party      Wii  2010       Misc
# 260    261      Big Brain Academy: Wii Degree      Wii  2007       Misc
# 337    338                          Wii Music      Wii  2008       Misc
# 1323  1324  PokePark Wii: Pikachu's Adventure      Wii  2009  Adventure
#
#      Publisher  North America  Europe  Japan  Rest of World  Global  Review
# ...

# %%
df2['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'PS2', 'SNES', 'X360', 'GBA', 'PS3',
#        'N64', 'PC', 'PS', 'XB', '3DS', 'PSP', 'GC', 'GEN', 'DC', 'SAT',
#        'WiiU', 'SCD', 'PSV'], dtype=object)

# %%
df2['Publisher'].sort_values(ascending= False).unique()
# Out:
# array(['id Software', 'Westwood Studios',
#        'Warner Bros. Interactive Entertainment', 'Vivendi Games',
#        'Virgin Interactive', 'Video System', 'Valve Software', 'Valve',
#        'Universal Interactive', 'Ubisoft', 'Tomy Corporation', 'Titus',
#        'Tecmo Koei', 'TalonSoft', 'Take-Two Interactive', 'THQ',
#        'TDK Mediactive', 'Success', 'Square Enix', 'Square EA', 'Square',
#        'SouthPeak Games', 'Sony Online Entertainment',
#        'Sony Computer Entertainment', 'Sega', 'Sammy Corporation', 'SCi',
#        'Russel', 'Rising Star Games', 'RedOctane',
#        'Red Storm Entertainment', 'Red Orb', 'Rage Software', 'RTL',
#        'Psygnosis', 'Play It', 'Pinnacle', 'Pacific Century Cyber Works',
#        'Ocean', 'Nintendo', 'Natsume', 'Namco Bandai Games', 'NCSoft',
#        'Mindscape', 'Midway Games', 'Microsoft Game Studios',
#        'Microprose', 'Maxis', 'Mastertronic', 'Majesco Entertainment',
#        'MTV Games', 'LucasArts', 'Level 5',
# ...

# %%
df2['Year'].sort_values(ascending= False).unique()
# Out:
# array([2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002,
#        2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991,
#        1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983], dtype=int64)

# %%
df2.dtypes
# Out:
# Rank               int64
# Game Title        object
# Platform          object
# Year               int64
# Genre             object
# Publisher         object
# North America    float64
# Europe           float64
# Japan            float64
# Rest of World    float64
# Global           float64
# Review           float64
# dtype: object

# %%
qwe= df2[(df2['Platform'] == 'DS') & (df2['Year'] == 2006) & (df2['Genre'] == 'Platform')]

# %%
qwe
# Out:
#      Rank             Game Title Platform  Year     Genre Publisher  \
# 5       6  New Super Mario Bros.       DS  2006  Platform  Nintendo
# 440   441      Yoshi's Island DS       DS  2006  Platform  Nintendo
# 715   716     Kirby Squeak Squad       DS  2006  Platform  Nintendo
#
#      North America  Europe  Japan  Rest of World  Global  Review
# 5            10.85    8.87   6.48           2.88   29.08   90.00
# 440           1.41    0.04   1.10           0.14    2.69   86.00
# 715           0.77    0.01   1.05           0.08    1.91   72.24

# %%
year= df['Year'].sort_values(ascending= False).unique()

# %%
type(year)
# Out:
# numpy.ndarray

# %%
year2= year.tolist()

# %%
type(year2)
# Out:
# list

# %%
platform= df2['Platform'].sort_values(ascending= True).unique()

# %%
type(platform)
# Out:
# numpy.ndarray

# %%
df2.columns
# Out:
# Index(['Rank', 'Game Title', 'Platform', 'Year', 'Genre', 'Publisher',
#        'North America', 'Europe', 'Japan', 'Rest of World', 'Global',
#        'Review'],
#       dtype='object')

# %%
type(df2.groupby('Year').count())
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df2.groupby('Year').count()
# Out:
#       Rank  Game Title  Platform  Genre  Publisher  North America  Europe  \
# Year
# 1983     6           6         6      6          6              6       6
# 1984     9           9         9      9          9              9       9
# 1985     6           6         6      6          6              6       6
# 1986    12          12        12     12         12             12      12
# 1987     7           7         7      7          7              7       7
# 1988     9           9         9      9          9              9       9
# 1989     9           9         9      9          9              9       9
# 1990    13          13        13     13         13             13      13
# 1991    10          10        10     10         10             10      10
# 1992    20          20        20     20         20             20      20
# 1993    12          12        12     12         12             12      12
# 1994    21          21        21     21         21             21      21
# ...
